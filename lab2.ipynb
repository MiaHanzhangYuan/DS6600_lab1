# %%
import numpy as np
import pandas as pd
import requests
import json
from ydata_profiling import ProfileReport
from bs4 import BeautifulSoup
import os

# %% [markdown]
# # 1

# %%
ds=pd.read_excel("https://demographics.coopercenter.org/sites/demographics/files/media/files/2020-07/Census_2019_RaceEstimates_forVA_0.xls", header = 4).drop(index=[0,1,2],columns=['Unnamed: 4','Unnamed: 6','Unnamed: 8','Unnamed: 10','Unnamed: 12'])

# %%
ds
# Out:
#       FIPS         Jurisdiction  Total Population  White Alone  \
# 3      1.0      Accomack County           32316.0      21899.0
# 4      3.0     Albemarle County          109330.0      89388.0
# 5      5.0     Alleghany County           14860.0      13783.0
# 6      7.0        Amelia County           13145.0      10050.0
# 7      9.0       Amherst County           31605.0      24299.0
# ..     ...                  ...               ...          ...
# 131  800.0         Suffolk city           92108.0      47993.0
# 132  810.0  Virginia Beach city          449974.0     303182.0
# 133  820.0      Waynesboro city           22630.0      18265.0
# 134  830.0    Williamsburg city           14954.0      11013.0
# 135  840.0      Winchester city           28078.0      22862.0
#
#      African American Alone  Asian Alone  Other Races Alone  Two or more races
# 3                    9304.0        257.0              293.0              563.0
# ...

# %%
h1 = ProfileReport(ds,
                       title = '1',
                       html = {'style':{'full_width': True}},
                       minimal = True)
h1.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.5.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-10-12 00:41:58.660401&quot;&gt;&lt;title&gt;1&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # 2

# %% [markdown]
# (a)

# %%
geniuskey = os.getenv('geniuskey')
r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']

headers = {'User-Agent': useragent,
 'From': 'ynx9zm@virginia.edu', #use your own email here
 'Authorization': 'Bearer ' + geniuskey}

root = 'http://api.genius.com'
endpoint = '/search'

parameters = {'q': 'lizzo'}
             #'api_key': geniuskey

r = requests.get(root + endpoint,
                params = parameters,
                headers = headers)

myjson = json.loads(r.text)

lizzoid = myjson['response']['hits'][0]['result']['primary_artist']['id']

# %% [markdown]
# (b)

# %%
endpoint=f'/artists/{lizzoid}'

parameters = {'format': 'json',
             'api_key': geniuskey}

r = requests.get(root + endpoint,
                params = parameters,
                headers = headers)
myjson = json.loads(r.text)
myjson['response']['artist']['alternate_names']
# Out:
# ['Melissa Viviane Jefferson', 'Melissa Jefferson']

# %% [markdown]
# (b)

# %%
endpoint=f'/artists/{lizzoid}/songs'
parameters = {'format': 'json',
              'sort': 'popularity',
             'api_key': geniuskey}
r = requests.get(root + endpoint,
                params = parameters,
                headers = headers)
myjson = json.loads(r.text)

# %%
songs = myjson['response']['songs']

# %%
[i['title'] for i in songs]
# Out:
# ['Truth Hurts',
#  'Juice',
#  'Good as Hell',
#  'Rumors',
#  'About Damn Time',
#  'Boys',
#  'F2F',
#  'Grrrls',
#  'Tempo',
#  'Cuz I Love You',
#  'Like a Girl',
#  'Good as Hell (Remix)',
#  'Soulmate',
#  'Blame It on Your Love',
#  'Jerome',
#  'Pink',
#  'Special',
#  'Water Me',
#  'Truth Hurts',
#  'Scuse Me']

# %% [markdown]
# # 3

# %% [markdown]
# (a)

# %%
User-Agent: *
  Disallow: /songs/*/metadata
  Disallow: /songs/*/comments
  Disallow: /users/*/top_artist_iq_rank
  Disallow: /artists/*/top_iq_earners
  Disallow: /comments/for_profile_page
  Disallow: /bagon/*
  Disallow: /mecha/*
  Disallow: /account/unsubscribe/*
  Disallow: /email_notifications/*/unsubscribe
  Disallow: /annotations/*/report_as_abusive
  Disallow: /songs/for_profile_page
  Disallow: /api$
  Disallow: /api/*
  Disallow: /search?*
  Disallow: /*/*/leaderboard
  Disallow: /songs/*/apple_music_player*
  Disallow: /songs/*/show_amp_header_play_toggle*

  User-agent: Uniscan
  Disallow: /

  User-agent: Searchie
  Disallow: /

# %%
(b)

# %%
def display(page):
    for j in page:
        for i in j:
            try:
                print(i.find('span',attrs={'class':"ReferentFragmentdesktop__Highlight-sc-110r0d9-1 jAzSMw"}).getText())
            except:
                print(i.getText())
                
url = 'https://genius.com/Lizzo-good-as-hell-lyrics'
r = requests.get(url, headers= headers)

lyric = BeautifulSoup(r.text,"html.parser").find_all('div',attrs={'class':'Lyrics__Container-sc-1ynbvzw-1 kUgSbL'})

page = BeautifulSoup(r.text,"html.parser")

# %%
display(lyric)
# Out:
# [Chorus]
#
# I do my hair toss, check my nails
#
#
#
# Baby, how you feelin'? (Feelin' good as hell)
#
# Hair toss, check my nails
#
# Baby, how you feelin'? (Feelin' good as hell)
#
#
# [Verse 1]
#
# Woo, child, tired of the bullshit
#
# Go on, dust your shoulders off, keep it moving
#
# Yes, Lord, tryna get some new shit
#
# In there, swimwear, going-to-the-pool shit
#
# Come now, come dry your eyes
#
# You know you a star, you can touch the sky
#
# I know that it's hard, but you have to try
#
# If you need advice, let me simplify
#
#
# [Pre-Chorus]
#
# If he don't love you anymoreJust walk your fine ass out the door
#
#
#
#
# [Chorus]
#
# I do my hair toss, check my nailsBaby, how you feelin'? (Feelin' good as hell)Hair toss, check my nailsBaby, how you feelin'? (Feelin' good as hell)(Feeling good as hell)Baby, how you feelin'? (Feelin' good as hell)
#
#
#
# [Verse 2]
#
# Woo, girl, need to kick off your shoes
#
# Gotta take a deep breath, time to focus on you
#
# ...

# %% [markdown]
# (c)

# %%
url = 'https://genius.com/albums/Lizzo/Cuz-i-love-you'
r = requests.get(url, headers= headers)
r
mysoup = BeautifulSoup(r.text,"html.parser")

# %%
import urllib.request

list = [link.get('href') for link in page.find_all('a', attrs={'class': 'Link__StyledLink-rwn6i6-0 coYbdh'})]
track = [i for i in list if 'https://genius.com/Lizzo-' in i]

# %%
track
# Out:
# ['https://genius.com/Lizzo-cuz-i-love-you-lyrics',
#  'https://genius.com/Lizzo-like-a-girl-lyrics',
#  'https://genius.com/Lizzo-juice-lyrics',
#  'https://genius.com/Lizzo-soulmate-lyrics',
#  'https://genius.com/Lizzo-jerome-lyrics',
#  'https://genius.com/Lizzo-cry-baby-lyrics',
#  'https://genius.com/Lizzo-tempo-lyrics',
#  'https://genius.com/Lizzo-exactly-how-i-feel-lyrics',
#  'https://genius.com/Lizzo-better-in-color-lyrics',
#  'https://genius.com/Lizzo-heaven-help-me-lyrics',
#  'https://genius.com/Lizzo-lingerie-lyrics',
#  'https://genius.com/Lizzo-boys-lyrics',
#  'https://genius.com/Lizzo-water-me-lyrics',
#  'https://genius.com/Lizzo-good-as-hell-remix-lyrics',
#  'https://genius.com/Lizzo-good-as-hell-radio-edit-lyrics',
#  'https://genius.com/Lizzo-good-as-hell-bndr-remix-lyrics',
#  'https://genius.com/Lizzo-good-as-hell-remix-lyrics']

# %%
for N in track:
    r = requests.get(N, headers= headers)
    page = BeautifulSoup(r.text,"html.parser").find_all('div',attrs={'class':'Lyrics__Container-sc-1ynbvzw-1 kUgSbL'})
    print()
    display(page)
# Out:
# [Intro]
#
# I'm cryin’ 'cause I love you, oh(Ya ya ya, ya ya, ya ya)
#
#
#
#
# [Verse 1]
#
# Never been in love before
#
# What the fuck are fucking feelings, yo?
#
# Once upon a time, I was a ho
#
#
#
# I don't even wanna ho no mo’
#
# Got you something from the liquor store
#
# Little bit of Lizzo and some Mo
#
# Tryna open up a little mo'
#
# Sorry if my heart a little slow
#
#
# [Chorus]
#
# I thought that I didn't care
#
# I thought I was love-impaired
#
# But baby, baby
#
# I don't know what I'm gon' do
#
# I'm cryin' ’cause I love you, oh
#
#
#
# Yes, you (Ya ya, ya ya)
#
#
# [Verse 2]
#
# Got me standing in the rainGotta get my hair pressed again
#
#
#
# I would do it for you all, my friend
#
# Ready, baby? Will you be my man?
#
# Wanna put you on a plane
#
# Fly you out to wherever I am
#
# Catch you on the low, I was ashamed
#
# Now I’m crazy, 'bout to tat your name
#
#
#
# [Chorus]
#
# I thought that I didn’t care
#
# I thought I was love-impaired
#
# But baby, oh baby
#
# ...

# %% [markdown]
# # 4

# %%
root = 'https://maps.spirithalloween.com'
domain='domain'
endpoint = f'/api/getAsyncLocations?template={domain}&level={domain}'
headers = {'User-Agent': useragent,
 'From': 'ynx9zm@virginia.edu'}
parameters = {'format': 'json',
             "render": "all",
            "limit": 2000,
            "radius": 1800,
            "zoom": "autofit",
            "mapContainerId": "gmap",
            "listContainer": ".map-list",
            "psid": 1,
            "did": "5555",
            "lat": 40.380028,
            "lng": -97.910156}
r = requests.get(root + endpoint,
                params = parameters,
                headers = headers)

# %%
myjson = json.loads(r.text)

# %%
result = []
for i in myjson['markers']:
    address = BeautifulSoup(i['info']).find('div', attrs={'class':'address-two'}).getText()
    result.append(address)

# %%
formerlocs = [i for i in result if 'Former' in i]

# %%
pd.Series(formerlocs).value_counts()
# Out:
# Former Tuesday Morning        108
# Former Bed Bath   Beyond       91
# Former Sears                   67
# Former Bed Bath and Beyond     66
# Former CVS                     38
#                              ...
# Former Hibbett                  1
# Former Shoppers DrugMart        1
# Former Burn Fitness             1
# Former Papaya                   1
# Former Cabelas                  1
# Name: count, Length: 439, dtype: int64
